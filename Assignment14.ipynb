# %% [markdown]
# <a href="https://colab.research.google.com/github/arath005/CSC221_arath005/blob/main/Assignment14.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
while True:
    input_str = input("\nEnter an expression (e.g., '13 / 5' or 'q' to quit): ")

    if input_str.lower() == 'q':
        break

    try:
        args = input_str.split()
        if len(args) != 3:
            print("Invalid input. Please enter an expression in the format 'number op number'.")
            continue

        num1 = float(args[0])
        operator = args[1]
        num2 = float(args[2])

        if operator == '+':
            result = num1 + num2
        elif operator == '-':
            result = num1 - num2
        elif operator == '*':
            result = num1 * num2
        elif operator == '/':
            if num2 != 0:
                result = num1 / num2
            else:
                print("Error: Division by zero.")
                continue
        else:
            print("Invalid operator. Please use +, -, *, or /.")
            continue

        print(f"{num1} {operator} {num2} = {result:.2f}")

    except ValueError:
        print("Invalid input. Please enter numeric values.")
    except Exception as e:
        print(f"An error occurred: {e}")
# Out:
# Enter an expression (e.g., '13 / 5' or 'q' to quit): 192897/232
# Invalid input. Please enter an expression in the format 'number op number'.
#
# Enter an expression (e.g., '13 / 5' or 'q' to quit): 3947 / 213
# 3947.0 / 213.0 = 18.53

# %%
# Assignment 13 Source File Generator
# DO NOT MODIFY

import random
def do_x_percent(n):
    chance = random.randint(0,99)
    return chance < n

_last_choice = "?"
def choose_character(include_str, exclude_str=''):
    global _last_choice
    chosen_character = random.choice(include_str)
    while chosen_character == _last_choice or chosen_character in exclude_str:
        chosen_character = random.choice(include_str)

    _last_choice = chosen_character
    return chosen_character

def rand_digit(exclude_str=''):
    return choose_character('0123456789', exclude_str)

def rand_vowel(exclude_str=''):
    return choose_character('aeiou', exclude_str)

def rand_consonant(exclude_str='qz'):
    return choose_character('bcdfghjklmnpqrstvwyz', exclude_str)

def gen_first_name():
    name = rand_consonant().upper() + rand_vowel()

    for i in range(random.randint(1, 2)):
        name += rand_consonant()
        name += rand_vowel()

    return name

def gen_last_name():
    name = random.choice(['', '', '', '', '', 'de ', 'el '])
    name += rand_consonant().upper() + rand_vowel()

    for i in range(random.randint(2, 3)):
        name += rand_consonant()
        name += rand_vowel()
        if do_x_percent(20):
            name += rand_vowel()

    return name

def gen_default_email(first_name, last_name):
    compacted_last = last_name.replace(' ', '')
    if do_x_percent(60):
        email = first_name[0].lower() + compacted_last[:4].lower()
        num = random.randint(1,7)
        email += f'{num:03d}@plattsburgh.edu'
    else:
        email = first_name.lower() + compacted_last[0].lower()
        domain = random.randint(1,3)
        if domain == 1:
            email += '@gmail.com'
        if domain == 2:
            email += '@yahoo.com'
        if domain == 3:
            email += '@msn.com'

    return email

def gen_phone_number():
    phone_number = '+' + str(random.randint(1,42))

    phone_number += ' '
    phone_number += rand_digit('0')
    for i in range(2):
       phone_number += rand_digit()

    phone_number += ' '
    for i in range(random.randint(3,4)):
       phone_number += rand_digit()

    phone_number += ' '
    for i in range(random.randint(3,4)):
       phone_number += rand_digit()

    return phone_number

def gen_pastimes():
    pastime_set = set()
    num_pastimes = random.randint(0, 4)

    for i in range(num_pastimes):
        pastime = random.choice(
            ['tennis', 'piano', 'farming', 'fishing',
             'coding', 'swimming', 'singing', 'airplanes', 'dancing',
             'reading', 'saxophone', 'cards', 'hiking', 'bicycling', 'running',
             'javelin', 'sewing', 'painting', 'poetry'])
        pastime_set.add(pastime)

    pastime_string = ""
    first_time = True
    for pastime in pastime_set:
        if first_time:
            first_time = False
        else:
            pastime_string += ', '
            first_time = False
        pastime_string += pastime

    return pastime_string

# %%
# Assignment 13 Source File Generator
# DO NOT MODIFY

class Person:
    def __init__(self):
        self.first_name = gen_first_name()
        self.last_name = gen_last_name()
        self.email = gen_default_email(self.first_name, self.last_name)
        self.phone_number = gen_phone_number()
        self.pastimes = gen_pastimes()
    def __str__(self):
        ret = f'{self.first_name} {self.last_name}, {self.email}, {self.phone_number}'
        if len(self.pastimes) > 0:
          ret += f', {self.pastimes}'
        return ret
    def __lt__(self, other):
        return self.first_name < other.first_name
    def as_transmitted(self):
        return str(self)
    def as_received(self):
        receive_string = self.as_transmitted()

        # These are our "typical" random transmission errors :)
        if do_x_percent(80):
            receive_string = receive_string.replace('nn', 'nnn')
        if do_x_percent(40):
            receive_string = receive_string.replace('+', '++')
        if do_x_percent(60):
            receive_string = receive_string.replace('00', '0O')
        if do_x_percent(40):
            receive_string = receive_string.replace('.com', '_dot_com')
        if do_x_percent(20):
            receive_string = receive_string.replace('swimming', 'swiming')
        if do_x_percent(20):
            receive_string = receive_string.replace('plattsburgh', 'platsburgh')
        if do_x_percent(20):
            receive_string = receive_string.replace('plattsburgh', 'plattsburg')
        if do_x_percent(20):
            receive_string = receive_string.replace('plattsburgh', 'platsburg')
        if do_x_percent(20):
            receive_string = receive_string.replace('plattsburgh', 'plattsberg')
        if do_x_percent(20):
            receive_string = receive_string.replace(' ', '_', 7)

        return receive_string

# Example People and how they are garbled
random.seed(1)
people = [Person() for x in range(20)]
for person in sorted(people):
    print(person)
    print(person.as_received())
# Out:
# Banono Difiwopi, banonod@gmail.com, +20 351 7195 640, saxophone, swimming
# Banono Difiwopi, banonod@gmail.com, ++20 351 7195 640, saxophone, swimming
# Dese el Ronouteo, desee@msn.com, +27 143 8038 9093, singing, swimming
# Dese el Ronouteo, desee@msn.com, +27 143 8038 9093, singing, swiming
# Gula Sojabobo, gulas@gmail.com, +38 150 806 083, painting, airplanes, javelin
# Gula Sojabobo, gulas@gmail_dot_com, +38 150 806 083, painting, airplanes, javelin
# Hidehi Hisitaino, hhisi001@plattsburgh.edu, +17 839 0306 027, bicycling, painting, airplanes, sewing
# Hidehi Hisitaino, hhisi001@plattsburgh.edu, ++17 839 0306 027, bicycling, painting, airplanes, sewing
# Huli Vinietewa, hvini004@plattsburgh.edu, +5 625 961 914, reading, poetry
# Huli Vinietewa, hvini004@plattsburgh.edu, +5 625 961 914, reading, poetry
# Jimupe de Sufuyo, jdesu003@plattsburgh.edu, +28 390 6568 081, fishing, dancing
# Jimupe de Sufuyo, jdesu0O3@platsburgh.edu, ++28 390 6568 081, fishing, dancing
# Juyeta de Mubimaji, jdemu003@plattsburgh.edu, +28 341 8587 101, swimming
# Juyeta_de_Mubimaji,_jdemu0O3@platsburg.edu,_++28_341_8587_101, swimming
# Lukika el Noleusu, lelno005@plattsburgh.edu, +17 782 754 3134
# Lukika_el_Noleusu,_lelno005@plattsberg.edu,_++17_782_754_3134
# Megu de Cihiwei, megud@gmail.com, +29 684 8706 2470, poetry, piano, tennis
# Megu_de_Cihiwei,_megud@gmail_dot_com,_+29_684_8706_2470, poetry, piano, tennnis
# Meli Lowira, mlowi005@plattsburgh.edu, +25 341 908 2185, reading, bicycling, sewing, cards
# Meli_Lowira,_mlowi0O5@plattsburg.edu,_+25_341_908_2185,_reading, bicycling, sewing, cards
# Nute de Magohabi, nuted@yahoo.com, +35 427 2780 8196
# Nute de Magohabi, nuted@yahoo_dot_com, ++35 427 2780 8196
# Pabeve de Domejelau, pabeved@yahoo.com, +30 802 8459 686, javelin
# Pabeve de Domejelau, pabeved@yahoo_dot_com, +30 802 8459 686, javelin
# Pesi Ruhiuru, pruhi003@plattsburgh.edu, +19 978 9073 6258, farming, running
# Pesi Ruhiuru, pruhi003@plattsburg.edu, +19 978 9073 6258, farming, runnning
# Puye Liyodebe, pliyo005@plattsburgh.edu, +42 735 7365 3018, sewing, swimming
# Puye Liyodebe, pliyo005@plattsburg.edu, ++42 735 7365 3018, sewing, swimming
# Seyi de Rageidame, seyid@yahoo.com, +9 809 729 635
# Seyi de Rageidame, seyid@yahoo_dot_com, +9 809 729 635
# Tivo Pobunobe, tpobu005@plattsburgh.edu, +38 218 0107 434
# Tivo_Pobunobe,_tpobu0O5@plattsburgh.edu,_++38_218_0107_434
# Vavo Taciyuhe, vtaci001@plattsburgh.edu, +13 836 9574 682, singing, bicycling, painting, piano
# Vavo Taciyuhe, vtaci0O1@platsburg.edu, ++13 836 9574 682, singing, bicycling, painting, piano
# Vifo de Siwoyoewa, vifod@msn.com, +33 379 4279 580, bicycling, poetry, hiking
# Vifo_de_Siwoyoewa,_vifod@msn.com,_+33_379_4279_580, bicycling, poetry, hiking
# Walaci Bafakuha, wbafa006@plattsburgh.edu, +16 216 8484 5135
# Walaci Bafakuha, wbafa0O6@plattsberg.edu, ++16 216 8484 5135
# Yina Yukeodi, yyuke006@plattsburgh.edu, +5 457 2185 825, sewing, fishing
# Yina Yukeodi, yyuke006@plattsburgh.edu, ++5 457 2185 825, sewing, fishing

# %%
# Assignment 13 Source File Generator
# DO NOT MODIFY

# Creates a population of Person objects
# Writes them uncorrupted to source_file.txt
# Writes them as received to as_received[123].txt
# Most records go into only one file but some are duplicated in two files
def make_files(my_name, record_count=100):
    random.seed(hash(my_name))

    people = [Person() for x in range(record_count)]

    source_file = open('source.txt', 'w')
    received_file1 = open('as_received1.txt', 'w')
    received_file2 = open('as_received2.txt', 'w')
    received_file3 = open('as_received3.txt', 'w')

    all_files = [source_file, received_file1, received_file2, received_file3]

    for file in all_files:
        file.write('Name, Email, Phone, Pastimes\n')

    source_file_line_count = 0
    received_file1_line_count = 0
    received_file2_line_count = 0
    received_file3_line_count = 0
    for person in sorted(people):
        source_file.write(person.as_transmitted() + '\n')
        source_file_line_count += 1

        # These are all 3-bit numbers that have either 1 or 2 bits turned on
        #   with a bias to a single bit
        choice = random.choice([1, 2, 4, 1, 2, 4, 1, 2, 4, 1, 2, 4, 3, 5, 6])
        if choice & 1:
            received_file1.write(person.as_received() + '\n')
            received_file1_line_count += 1
        if choice & 2:
            received_file2.write(person.as_received() + '\n')
            received_file2_line_count += 1
        if choice & 4:
            received_file3.write(person.as_received() + '\n')
            received_file3_line_count += 1

    print(f'source_file written with {source_file_line_count} lines')
    print(f'received_file1 written with {received_file1_line_count} lines')
    print(f'received_file2 written with {received_file2_line_count} lines')
    print(f'received_file3 written with {received_file3_line_count} lines')

    for file in all_files:
        file.close()

# %%
make_files(my_name='Alex Rathbun', record_count=100000)

def read_received_file(file_name):
    try:
      corrected_records = []
      with open(file_name, 'r') as file:
        header_line = file.readline().strip()
        for line in file:
            corrected_records.append(line.strip())
      return corrected_records
    except:
      print('Error has occured in "read_received_file"')
def correct_received_records(received_records):
    try:
      corrected_records = []
      unique_records = set()

      for record in received_records:
          corrected_record = record
          corrected_record = corrected_record.replace('nnn', 'nn')
          corrected_record = corrected_record.replace('++', '+')
          corrected_record = corrected_record.replace('0O', '00')
          corrected_record = corrected_record.replace('_dot_com', '.com')
          corrected_record = corrected_record.replace('swiming', 'swimming')
          corrected_record = corrected_record.replace('platsburg', 'plattsburgh')
          corrected_record = corrected_record.replace('platsburgh', 'plattsburgh')
          corrected_record = corrected_record.replace('platsberg', 'plattsburgh')
          corrected_record = corrected_record.replace('_', ' ')
          corrected_record = corrected_record.replace('plattsburg', 'plattsburgh')
          corrected_record = corrected_record.replace('plattsberg', 'plattsburgh')
          corrected_record = corrected_record.replace('plattsburghh', 'plattsburgh')
          corrected_record = corrected_record.replace('plattsbeurghhh', 'plattsburgh')
          corrected_record = corrected_record.replace('plattsburghh', 'plattsburgh')

          if corrected_record not in unique_records:
              corrected_records.append(corrected_record)
              unique_records.add(corrected_record)

      return corrected_records
    except:
      print('Error has occured in "correct_received_records"')

def write_sorted_unique_records(records, output_file):
    try:
      with open(output_file, 'w') as file:
        unique_records = set()
        file.write("Name, Email, Phone, Pastimes\n")

        sorted_records = sorted(records, key=lambda x: x.split(",")[0])

        for record in sorted_records:
            if record not in unique_records:
                file.write(record + '\n')
                unique_records.add(record)
    except:
      print('Error has occured in "write_sorted_unique_records"')

def compare_files_ignore_order(file1, file2):
    try:
      with open(file1, 'r') as f1, open(file2, 'r') as f2:
          lines1 = sorted(f1.readlines(), key=lambda x: x.split(",")[0])
          lines2 = sorted(f2.readlines(), key=lambda x: x.split(",")[0])
      return lines1 == lines2
    except:
      print('Error has occured in "compare_files_ignore_order"')

source_file = 'source.txt'
received_files = ['as_received1.txt', 'as_received2.txt', 'as_received3.txt']
corrected_file = 'corrected.txt'

corrected_records = []

for received_file in received_files:
    received_records = read_received_file(received_file)
    corrected_records.extend(correct_received_records(received_records))

write_sorted_unique_records(corrected_records, corrected_file)

if compare_files_ignore_order(corrected_file, source_file):
    print('The files match.')
else:
    print('The files do not match. Differences in order have been ignored.')
# Out:
# source_file written with 100000 lines
# received_file1 written with 39868 lines
# received_file2 written with 39974 lines
# received_file3 written with 40190 lines
# The files match.
